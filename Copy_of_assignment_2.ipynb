# %% [markdown]
# <a href="https://colab.research.google.com/github/Sameya-eng/Skill-Morph-Assignments/blob/main/Copy_of_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.
name="Samia"
age=35
favorite_color="pink"
print("Name is:", name)
print("Age:", age)
print("Favorite_color:", favorite_color)
# Out:
# Name is: Samia
# Age: 35
# Favorite_color pink

# %%
# 2. creating a variable
name = "Sameya"
address = 'Dhaka'
age = 25
price = 99.99
is_valid = True
has_paid = False
result = None
print(type(name))
print(type(address))
print(type(has_paid))
print(type(result))
print(type(is_valid))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# <class 'bool'>

# %%
# 3.
length= 7
width= 5
area=length * width
perimeter = 2 * (length + width)

print("Area of rectangle:", area)
print("Perimeter of rectangle:", perimeter)
# Out:
# Area of rectangle: 35
# Perimeter of rectangle: 24

# %%
#4.
foods = ["Biryani", "Panta Bhat", "Hilsha Fish", "Fuchka", "Kacchi"]

first_food = foods[0]
last_food = foods[-1]

print("First food:", first_food)
print("Last food:", last_food)
# Out:
# First food: Biryani
# Last food: Kacchi

# %%
#5.
numbers = [12, 5, 8, 3, 20]
numbers.append(15)
print("Without sorting list:", numbers)

# Remove one number (example: remove 8)
numbers.remove(8)

# Sort the list
numbers.sort()

print("Final sorted list:", numbers)
# Out:
# list: [12, 5, 8, 3, 20, 15]
# Final sorted list: [3, 5, 12, 15, 20]

# %%
#6.
my_info = {
    "name": "Samia Akter",
    "age": 22,
    "favorite_color": "Blue",
    "hobby": "Reading books"
}

print(my_info)
# Out:
# {'name': 'Samia Akter', 'age': 22, 'favorite_color': 'Blue', 'hobby': 'Reading books'}

# %%
# 7.
# Tuple with latitude and longitude of Cox's Bazar
location = (21.4272, 92.0058)

print(location)
# Out:
# (21.4272, 92.0058)

# %%
# 8.
# Create two sets of colors
set1 = {"red", "blue", "green"}
set2 = {"yellow", "blue", "black"}

# Find union and intersection
union_result = set1.union(set2)
intersection_result = set1.intersection(set2)

print("Union:", union_result)
print("Intersection:", intersection_result)
# Out:
# Union: {'yellow', 'red', 'green', 'black', 'blue'}
# Intersection: {'blue'}
