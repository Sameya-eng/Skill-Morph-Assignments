# %%
# 1.
name="Samia"
age=35
favorite_color="pink"
print("Name is:", name)
print("Age:", age)
print("Favorite_color:", favorite_color)
# Out:
# Name is: Samia
# Age: 35
# Favorite_color pink

# %%
# 2. creating a variable
name = "Sameya"
address = 'Dhaka'
age = 25
price = 99.99
is_valid = True
has_paid = False
result = None
print(type(name))
print(type(address))
print(type(has_paid))
print(type(result))
print(type(is_valid))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# <class 'bool'>
